# %%
my_list=[9,3,5,6,2,3,6]
my_list
# Out:
# [9, 3, 5, 6, 2, 3, 6]

# %%
for i in my_list:
    print(i)
    #listeyi tek tek dolaştı
# Out:
# 9
# 3
# 5
# 6
# 2
# 3
# 6

# %%
for  i in range(len(my_list)):
    #listeyi elemn sayısı kadar dolaş
    print(i,my_list[i])
# Out:
# 0 9
# 1 3
# 2 5
# 3 6
# 4 2
# 5 3
# 6 6

# %%
def my_function_1(my_list=[9,3,5,6,2,3,6]):
    for i in range(len(my_list)):
        print(i,my_list[i])
        my_list[i]=my_list[i]+1
    print(my_list)

# %%
my_function_1()
# Out:
# 0 9
# 1 3
# 2 5
# 3 6
# 4 2
# 5 3
# 6 6
# [10, 4, 6, 7, 3, 4, 7]

# %%
#my_function_1(['bir',2,3,4,54,5,56,6]) #hata cıktısı 0 bir ve hata

# %%
#my_function_1([1,2,3,4,54,5,56,6]) listeyi değiştirrebiliriz.

# %%
my_function_1()#artmış halini yazar
# Out:
# 0 10
# 1 4
# 2 6
# 3 7
# 4 3
# 5 4
# 6 7
# [11, 5, 7, 8, 4, 5, 8]

# %%
import numpy as np
my_list_1=np.array(list([9,3,5,6,2,3,6])) #ndarray
my_list_1
# Out:
# array([9, 3, 5, 6, 2, 3, 6])

# %%
my_list_1+1
# Out:
# array([10,  4,  6,  7,  3,  4,  7])

# %%
# hata verir => my_list+1 çünkü ndarray degil

# %%
def my_function_2(my_array=np.array(list([9,3,5,6,2,3,6]))):
    return my_array-10

# %%
my_function_2()
# Out:
# array([-1, -7, -5, -4, -8, -7, -4])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im_1=plt.imread('istanbul.jpg')
plt.imshow(im_1)
plt.show()

# %%
im_1.ndim,im_1.shape
#im_1=im_1+100
#plt.imshow(im_1)
#plt.show()
# Out:
# (3, (344, 620, 3))

# %%
m,n,p=im_1.shape
im_2=np.zeros((m,n,3),dtype=int)
m,n,im_2.shape
for m in range(im_1.shape[0]):
    for n in range(im_1.shape[1]):
        im_2[m,n,0]=im_1[m,n,0]+100 #r bantını 
        im_2[m,n,1]=im_1[m,n,1] #g
        im_2[m,n,2]=im_1[m,n,2] #b
plt.imshow(im_2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# gönderilen resmin kırmızı değerini gönderilen s değerine göre arttıran/azaltan fonksiyon

# %%
def my_f_3(im_100,s=50): #s artım mıktarı
    
    im_1=im_100
    m,n,p=im_1.shape
    im_2=np.zeros((m,n,3),dtype=int)
    #m,n,im_2.shape kontrol için değerler kaybolmuş mu diye

    for m in range (im_1.shape[0]):
        for n in range(im_1.shape[1]):
            im_2[m,n,0]=im_1[m,n,0]+s #kırmızı yogunlugunu değiştirme
            im_2[m,n,1]=im_1[m,n,0]
            im_2[m,n,2]=im_1[m,n,0]

    return im_2
plt.imshow(my_f_3(im_1))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #gönderilen mxn lik resmi m/2 x n/2 lik yapan fonksiyon

# %%
def my_f_4(im_500): 
    
    m,n,p=im_500.shape
    new_m=int(m/2)
    new_n=int(n/2)
   
    im_600=np.zeros((new_m,new_n),dtype=int)
    for m in range (new_m):
        for n in range(new_n):
             s0=(im_500[m*2,n*2,0]+im_500[m*2,n*2,1]+im_500[m*2,n*2,2])/3
#            s0=(im_500[m,n,0]+im_500[m,n,1]+im_500[m,n,2])/3 #bulundugu yerdekı tum rgb degerlerını aldı
            
#            s1=(im_500[m,n+1,0]+im_500[m,n+1,1]+im_500[m,n+1,2])/3 #bir sagdakı
#           
#            s2=(im_500[m+1,n,0]+im_500[m+1,n,1]+im_500[m+1,n,2])/3 #bır soldakı
#            
#            s3=(im_500[m+1,n+1,0]+im_500[m+1,n+1,1]+im_500[m+1,n+1,2])/3 #caprazdakı
            
#            s=(s0+s1+s2+s3)/4
#            im_600[m,n]=int(s)

             im_600[m,n]=int(s0)
             
    return im_600

# %%
im_5=my_f_4(im_1)
plt.imshow(im_5)
plt.show()
plt.imsave("ist_1.jpg",im_5)
# Out:
# C:\Users\melis\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in ubyte_scalars
#   # Remove the CWD from sys.path while we load stuff.

# %%
im_2=my_f_4(im_1)
plt.imshow(im_2,cmap='gray')
plt.show(im_2)
# Out:
# C:\Users\melis\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in ubyte_scalars
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-c309a0a49d7c> in <module>
#       1 im_2=my_f_4(im_1)
#       2 plt.imshow(im_2,cmap='gray')
# ----> 3 plt.show(im_2)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      43         # only call close('all') if any to close
#      44         # close triggers gc.collect, which can be slow
# ---> 45         if close and Gcf.get_all_fig_managers():
#      46             matplotlib.pyplot.close('all')
#      47
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
